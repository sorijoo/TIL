# %% [markdown]
# ## 네이버 금융 뉴스기사 수집
# * [삼성전자 : 네이버 금융](https://finance.naver.com/item/news.naver?code=005930)
#
# ```
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <title>네이버 금융</title>
#
# <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220511192542/css/newstock.css">
# <style data-emotion="css" data-s=""></style>
# </head>
#
#
# <body>
# <script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220511192542/js/jindo.min.ns.1.5.3.euckr.js"></script>
# 		<div class="tb_cont">
# 			<div class="tlline2">
# 				<strong><span class="red03">종목</span>뉴스</strong>
# 				<!-- [D] 선택시 blind 태그 추가 -->
# 				<div class="info_txt">종목뉴스 안내<a href="#" onclick="togglePannel('layer_section'); clickcr(this,'stn.ninfo','','',event); return false;" class="btn_info_layer"><img src="https://ssl.pstatic.net/static/nfinance/2017/10/13/btn_help2.png" alt="상세 설명"></a>
# 					<div class="layer_section" id="layer_section" style="display:none">
# 						<strong>네이버 증권 종목뉴스 안내</strong>
# 						<p class="txt">
# 							AI(인공지능 검색기술)을 이용한 종목 관련 뉴스입니다. <br>관련뉴스는 자동으로 묶어 보여줍니다.
# 							<br>
# 							<span class="txt_opt">
# 								검색영역 옵션
# 								<br>
# 								제목 : 제목에서 종목명이 검색된 결과입니다. <br>
# 								내용 : 제목과 본문에서 종목명이 검색된 결과입니다.
# 							</span>
# 						</p>
# 						<a href="#" onclick="togglePannel('layer_section'); return false;" class="btn_close"><span class="blind">닫기</span></a>
# 					</div>
# 				</div>
# 			</div>
#
# 			<table summary="종목뉴스의 제목, 정보제공, 날짜" cellspacing="0" class="type5">
# 				<caption>종목뉴스</caption>
# 				<colgroup>
# 					<col>
# 					<col width="130px">
# 					<col width="110px">
# 				</colgroup>
# 				<thead>
# 					<tr>
# 						<th scope="col">제목</th>
# 						<th scope="col">정보제공</th>
# 						<th scope="col">날짜</th>
# 					</tr>
# 				</thead>
#
# 		 		<tbody>
#
#  							<tr class="first">
# 	 							<td class="title">
# 									<a href="/item/news_read.naver?article_id=0004836222&amp;office_id=014&amp;code=005930&amp;page=1&amp;sm=title_entity_id.basic" class="tit" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">삼성, 포켓몬 이어 뚱랑이 갤Z플립3에 입힌다</a>
#
# 								</td>
# 								<td class="info">파이낸셜뉴스</td>
# 								<td class="date"> 2022.05.15 11:52</td>
#  							</tr>
#
#
#  							<tr>
# 	 							<td class="title">
# 									<a href="/item/news_read.naver?article_id=0001990771&amp;office_id=016&amp;code=005930&amp;page=1&amp;sm=title_entity_id.basic" class="tit" onclick="clickcr(this,'stn.ntitclust','','',event);" target="_top">삼성전자, 16일부터 갤럭시 Z 플립3 '무직타이거 에디션' 한정 판매</a>
#
# 								</td>
# 								<td class="info">헤럴드경제</td>
# 								<td class="date"> 2022.05.15 11:41</td>
#  							</tr>
#
# 				</tbody>
# 			</table>
#
# 			<!--- 종목뉴스 끝--->
# 			<!--- 페이지 네비게이션 시작--->
#
# 			<table summary="페이지 네비게이션 리스트" class="Nnavi" align="center">
# 				<caption>페이지 네비게이션</caption>
# 				<tbody><tr>
#
#
#
# 		                <td class="on">
# 				<a href="/item/news_news.nhn?code=005930&amp;page=1&amp;sm=title_entity_id.basic&amp;clusterId=" onclick="clickcr(this,'stn.npag','','',event);">1</a>
# 				</td>
#                 <td>
# 				<a href="/item/news_news.nhn?code=005930&amp;page=2&amp;sm=title_entity_id.basic&amp;clusterId=" onclick="clickcr(this,'stn.npag','','',event);">2</a>
# 				</td>
# 		                <td class="pgR">
# 				<a href="/item/news_news.nhn?code=005930&amp;page=11&amp;sm=title_entity_id.basic&amp;clusterId=" onclick="clickcr(this,'stn.npag','','',event);">
# 				다음<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
# 		                <td class="pgRR">
# 				<a href="/item/news_news.nhn?code=005930&amp;page=1269&amp;sm=title_entity_id.basic&amp;clusterId=" onclick="clickcr(this,'stn.npag','','',event);">맨뒤
# 				<img src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8" height="5" alt="" border="0">
# 				</a>
# 				</td>
#
# 				</tr>
# 			</tbody></table>
#
#
# 	<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20220511192542/js/lcslog.js"></script>
# </div>
# </body>
# </html>
# ```

# %% [markdown]
# ## pandas만으로 데이터 수집하기

# %%
# pandas 불러오기
import pandas as pd

# %% [markdown]
# ## 검색 값 설정하기
# * 웹사이트에서 검색한 URL 안에 우리의 검색어가 들어가 있습니다.
# * 이렇게 검색어를 URL에 붙여서 넘기는 문구를 쿼리스트링이라고 부릅니다.
# * 이 문자열을 검색어에 맞게 변경해 줍니다.
# * 쿼리스트링 : 쿼리 문자열은 지정된 매개변수에 값을 할당하는 Uniform Resource Locator의 일부입니다. 쿼리 문자열에는 일반적으로 웹 브라우저나 기타 클라이언트 응용 프로그램에서 기본 URL에 추가한 필드가 포함됩니다.
#
# <img src="https://media.vlpt.us/images/keywookim/post/d23e05e7-0cfb-4347-ab89-f1b8a3d170c8/creating_query_strings1.png">

# %%
print("https://finance.naver.com/item/news_news.nhn?code=005930&page=1&sm=title_entity_id.basic&clusterId=")
# Out:
# https://finance.naver.com/item/news_news.nhn?code=005930&page=1&sm=title_entity_id.basic&clusterId=

# %%
# 수집할 url을 가져옵니다.
item_code = "005930"
item_name = "삼성전자"
page_no = 1

# %%
# url
url = f"https://finance.naver.com/item/news_news.nhn?code={item_code}&page={page_no}&sm=title_entity_id.basic&clusterId="

print(url)
# Out:
# https://finance.naver.com/item/news_news.nhn?code=005930&page=1&sm=title_entity_id.basic&clusterId=

# %% [markdown]
# ## read_html 로 수집하기
# * 네이버 금융의 주가 기사를 read_html로 수집해서 table 이라는 변수에 담습니다.

# %%
# 수집결과 는 table이라는 변수에 담아주세요.
# table
table = pd.read_html(url, encoding="cp949")


len(table)
# Out:
# 4

# %%
table[1]
# Out:
#                                     0      1                 2
# 0  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’   이데일리  2022.05.17 09:51
# 1  삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'  아시아경제  2022.05.17 09:07
# 2    여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’  헤럴드경제  2022.05.17 08:58
# 3      비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동  머니투데이  2022.05.17 08:43

# %% [markdown]
# ## 데이터프레임으로 만들기
# * 위에서 수집한 결과 중 table 변수 안에 있는 0번째 인덱스 값을 가져와서 df 라는 변수에 담아주세요.

# %%
# table의 0번째 인덱스 값을 df 라는 변수에 담습니다.
df = table[0]
table[1].columns = table[0].columns
table[1]
# Out:
#                                    제목   정보제공                날짜
# 0  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’   이데일리  2022.05.17 09:51
# 1  삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'  아시아경제  2022.05.17 09:07
# 2    여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’  헤럴드경제  2022.05.17 08:58
# 3      비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동  머니투데이  2022.05.17 08:43

# %% [markdown]
# ## 반복문으로 데이터 모두 가져오기
# * for 문을 사용해 table 이라는 변수 안에 있는 값을 모두 가져오기
# * temp_list 에 수집한 값을 담아주세요.

# %%
# temp_list = []
# for news in table:
temp_list = []
cols = table[0].columns
for news in table[:-1]: #마지막 인덱스에는 페이지 번호 들어 있어서 제외
    news.columns = cols #연관 기사랑 컬럼이름이 달라서 맞춰 준 것
    temp_list.append(news)

# %% [markdown]
# ## 수집한 데이터 하나의 데이터프레임으로 합치기
#
# <img src="https://pandas.pydata.org/docs/_images/merging_concat_basic.png">
#
# * [Merge, join, concatenate and compare documentation](https://pandas.pydata.org/docs/user_guide/merging.html#merge-join-concatenate-and-compare)
#
# * concat :
#     * axis=0 행을 기준으로 위아래로 같은 컬럼끼리 값을 이어 붙여 새로운 행을 만듦
#     * axis=1 컬럼을 기준으로 인덱스가 같은 값을 옆으로 붙여 새로운 컬럼을 만듦

# %%
# pd.concat

df_temp = pd.concat(temp_list)
df_temp
# Out:
#                                                    제목  \
# 0                           비스포크 인기에 에어컨 생산 풀가동 나선 삼성
# 1   연관기사 목록  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’  이...
# 2                  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’
# 3                  삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'
# 4                    여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’
# 5                      비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동
# 6                 삼성운용, 美 ETF 산업·中 메타버스 ETF 등 2종 신규상장
# 7                        삼성家 사돈의 유통혁명…편의점이 마트·백화점 제쳤다
# 8                     대기업 1분기 매출 800조원 육박…삼성전자 부동의 1위
# 9                    "美ETF산업·中메타버스 투자"…삼성운용 ETF 2종 상장
# 10  연관기사 목록  삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장 파이낸...
# 11                  삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장
# 12                 삼성 반도체 핵심기술 중국에 유출…800억 챙긴 일당 '덜미'
# 13                    코스피, 기관 매수에 상승 출발…삼성전자 6.7만원 회복
# 14                  [1일IT템]삼성전자 "로블록스에서 팝스타의 꿈 도전하세요"
# 15                   포브스 "삼성, 세계 기술기업 2위→4위...공급망 발목"
# 16                     TSMC보다 한 발 빨랐다…삼성이 꺼낸 '비장의 무기'
# 0                  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’
# 1                  삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'
# 2                    여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’
# 3                      비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동
# 0                   삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장
#
#                                                  정보제공  \
# 0                                                매일경제
# 1   연관기사 목록  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’  이...
# 2                                                이데일리
# 3                                               아시아경제
# 4                                               헤럴드경제
# 5                                               머니투데이
# 6                                               머니투데이
# 7                                               헤럴드경제
# 8                                              한경비즈니스
# 9                                                이데일리
# 10  연관기사 목록  삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장 파이낸...
# 11                                             파이낸셜뉴스
# 12                                               한국경제
# 13                                               한국경제
# 14                                             파이낸셜뉴스
# 15                                              머니투데이
# 16                                               한국경제
# 0                                                이데일리
# 1                                               아시아경제
# 2                                               헤럴드경제
# 3                                               머니투데이
# 0                                              파이낸셜뉴스
#
#                                                    날짜
# 0                                    2022.05.17 10:44
# 1   연관기사 목록  비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’  이...
# 2                                    2022.05.17 09:51
# 3                                    2022.05.17 09:07
# 4                                    2022.05.17 08:58
# 5                                    2022.05.17 08:43
# 6                                    2022.05.17 10:35
# 7                                    2022.05.17 10:32
# 8                                    2022.05.17 10:10
# 9                                    2022.05.17 09:21
# 10  연관기사 목록  삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장 파이낸...
# 11                                   2022.05.17 09:20
# 12                                   2022.05.17 09:20
# 13                                   2022.05.17 09:17
# 14                                   2022.05.17 08:51
# 15                                   2022.05.17 08:12
# 16                                   2022.05.16 21:02
# 0                                    2022.05.17 09:51
# 1                                    2022.05.17 09:07
# 2                                    2022.05.17 08:58
# 3                                    2022.05.17 08:43
# 0                                    2022.05.17 09:20

# %% [markdown]
# ## 위에서 수집한 데이터에서 결측치를 제거합니다.

# %%
# dropna

df_temp = df_temp.dropna(how="any", axis=0).dropna(how="any", axis=1)

#any는 nan이 하나라도 있으면 그 행을 날리겠다 "all"은 전부 nan이면 날리겠다

# %% [markdown]
# ## 네이버 수집한 기사에서 "제목"에 "연관기사"가 들어가는 데이터를 제거합니다.
#
# * <font color="red">.str.contains 를 사용하며 조건의 반대에는 앞에 ~ 표시로 표현할 수 있습니다.</red>

# %%
df_temp[~df_temp["제목"].str.contains("연관기사")]
# Out:
#                                      제목    정보제공                날짜
# 0             비스포크 인기에 에어컨 생산 풀가동 나선 삼성    매일경제  2022.05.17 10:44
# 2    비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’    이데일리  2022.05.17 09:51
# 3    삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'   아시아경제  2022.05.17 09:07
# 4      여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’   헤럴드경제  2022.05.17 08:58
# 5        비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동   머니투데이  2022.05.17 08:43
# 6   삼성운용, 美 ETF 산업·中 메타버스 ETF 등 2종 신규상장   머니투데이  2022.05.17 10:35
# 7          삼성家 사돈의 유통혁명…편의점이 마트·백화점 제쳤다   헤럴드경제  2022.05.17 10:32
# 8       대기업 1분기 매출 800조원 육박…삼성전자 부동의 1위  한경비즈니스  2022.05.17 10:10
# 9      "美ETF산업·中메타버스 투자"…삼성운용 ETF 2종 상장    이데일리  2022.05.17 09:21
# 11    삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장  파이낸셜뉴스  2022.05.17 09:20
# 12   삼성 반도체 핵심기술 중국에 유출…800억 챙긴 일당 '덜미'    한국경제  2022.05.17 09:20
# 13      코스피, 기관 매수에 상승 출발…삼성전자 6.7만원 회복    한국경제  2022.05.17 09:17
# 14    [1일IT템]삼성전자 "로블록스에서 팝스타의 꿈 도전하세요"  파이낸셜뉴스  2022.05.17 08:51
# 15     포브스 "삼성, 세계 기술기업 2위→4위...공급망 발목"   머니투데이  2022.05.17 08:12
# 16       TSMC보다 한 발 빨랐다…삼성이 꺼낸 '비장의 무기'    한국경제  2022.05.16 21:02
# 0    비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’    이데일리  2022.05.17 09:51
# 1    삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'   아시아경제  2022.05.17 09:07
# 2      여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’   헤럴드경제  2022.05.17 08:58
# 3        비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동   머니투데이  2022.05.17 08:43
# 0     삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장  파이낸셜뉴스  2022.05.17 09:20

# %% [markdown]
# ## 위의 과정을 함수로 만듭니다.
# * 빈칸을 완성해 수집한 table 을 넘겨주면 데이터프레임을 반환하는 함수를 완성해 주세요.

# %%
# get_url item_code, page_no 를 넘기면 url 을 반환하는 함수


def get_url(item_code, page_no):
    """
    item_code, page_no 를 넘기면 url 을 반환하는 함수
    """
    url = f"https://finance.naver.com/item/news_news.nhn?code={item_code}&page={page_no}&sm=title_entity_id.basic&clusterId="
    return url


get_url(item_code, page_no)
# Out:
# 'https://finance.naver.com/item/news_news.nhn?code=005930&page=5&sm=title_entity_id.basic&clusterId='

# %%
page_no = 3
temp_url = get_url(item_code, page_no)
print(temp_url)
# Out:
# https://finance.naver.com/item/news_news.nhn?code=005930&page=3&sm=title_entity_id.basic&clusterId=

# %% [markdown]
# ## 뉴스 한 페이지를 수집하는 함수
# ```
# 1) URL 을 받아옴
# 2) read_html 로 테이블 정보를 받아옴
# 3) 데이터프레임 컬럼명을 ["제목", "정보제공", "날짜"]로 변경
# 4) temp_list 에 데이터프레임을 추가
# 5) concat 으로 리스트 병합하여 하나의 데이터프레임으로 만들기
# 6) 결측치 제거
# 7) 연관기사 제거
# 8) 데이터프레임 반환
# ```

# %%
# get_one_page_news 함수 만들기
def get_one_page_news(item_code, page_no):
    """
    get_url 에 item_code, page_no 를 넘겨 url 을 받아오고
    뉴스 한 페이지를 수집하는 함수
    1) URL 을 받아옴
    2) read_html 로 테이블 정보를 받아옴
    3) 데이터프레임 컬럼명을 ["제목", "정보제공", "날짜"]로 변경
    4) temp_list 에 데이터프레임을 추가
    5) concat 으로 리스트 병합하여 하나의 데이터프레임으로 만들기
    6) 결측치 제거
    7) 연관기사 제거
    8) 데이터프레임 반환
    """
    
    url = get_url(item_code, page_no)
    table = pd.read_html(url, encoding="cp949")
    cols = table[0].columns
    temp_list = []
    for news in table[:-1]:
        news.columns = cols
        temp_list.append(news)
    df_temp = pd.concat(temp_list)
    df_temp = df_temp.dropna(how="all", axis=0).dropna(how="all", axis=1)
    df = df_temp[~df_temp["제목"].str.contains("연관기사")]
    return df

# %% [markdown]
# * 아래 코드를 실행했을 때 수집된 데이터프레임이 출력된다면 잘 만들어진 것입니다.

# %%
page_no = 5

temp = get_one_page_news(item_code, page_no)
temp
# Out:
#                                            제목    정보제공                날짜
# 0                    삼성이 5년 전 만든 단편영화, 일본 홀렸다   머니투데이  2022.05.15 15:57
# 1               이번엔 무직타이거…삼성전자, 갤럭시Z플립3 한정 판매    이데일리  2022.05.15 14:46
# 2                 삼성전자, 7주째 외국인 순매도 1위…언제 오를까    이데일리  2022.05.15 13:12
# 3                     코스피 주간 개인 순매수 1위 '삼성전자'    이데일리  2022.05.15 10:08
# 5                    코스피 주간 외국인 순매도 1위 '삼성전자'    이데일리  2022.05.15 10:08
# 6          6만전자 지속에도 삼전 대거 사들이는 동학개미…여름에는 웃을까    매일경제  2022.05.15 09:21
# 7              “벽돌이야 뭐야…‘접는폰’ 무거웠죠?” 삼성 ‘살뺐다’   헤럴드경제  2022.05.14 21:20
# 8          “한국 홀대 일본에서 웬일이냐?” 삼성도 깜짝 놀란 ‘대반전’   헤럴드경제  2022.05.14 17:52
# 9         “반도체 1등 자리 못 내줘” 삼성 ‘야심’ 담긴 공장들이 온다   헤럴드경제  2022.05.14 17:17
# 10                 삼성, 구글과 협업한 ‘헬스 커넥트’ 연내 도입    이데일리  2022.05.14 16:06
# 11          삼성 18개 계열사, 공채 필기시험 'GSAT' 이틀간 진행    이데일리  2022.05.14 15:40
# 13  '4대그룹 유일 공채' 삼성 필기 온라인 진행… "난이도 예년과 비슷...   아시아경제  2022.05.14 15:36
# 14        삼성 공채 필기시험 'GSAT' 14~15일 이틀간 온라인 진행    조세일보  2022.05.14 15:28
# 15  삼성, '4대 그룹 유일 공채' GSAT 온라인으로 진행… "예년과 ...    서울경제  2022.05.14 15:12
# 16              삼성 고시 'GSAT', 오늘부터 이틀간 온라인 실시  파이낸셜뉴스  2022.05.14 11:07
# 17                      '삼성고시' 오늘부터 이틀간 온라인으로    매일경제  2022.05.14 10:06
# 18      ‘4대 그룹 중 유일한 공개채용’ 삼성 GSAT 이틀간 온라인 진행   헤럴드경제  2022.05.14 09:05
# 19  삼성 18개 계열사 채용고시 시작…GSAT 오늘부터 이틀간 온라인 진...    한국경제  2022.05.14 08:41
# 20          ‘4대그룹 유일 공채’ 삼성, 오늘부터 온라인 GSAT 실시    조선비즈  2022.05.14 08:19
# 0                    코스피 주간 외국인 순매도 1위 '삼성전자'    이데일리  2022.05.15 10:08
# 0   '4대그룹 유일 공채' 삼성 필기 온라인 진행… "난이도 예년과 비슷...   아시아경제  2022.05.14 15:36
# 1         삼성 공채 필기시험 'GSAT' 14~15일 이틀간 온라인 진행    조세일보  2022.05.14 15:28
# 2   삼성, '4대 그룹 유일 공채' GSAT 온라인으로 진행… "예년과 ...    서울경제  2022.05.14 15:12
# 3               삼성 고시 'GSAT', 오늘부터 이틀간 온라인 실시  파이낸셜뉴스  2022.05.14 11:07
# 4                       '삼성고시' 오늘부터 이틀간 온라인으로    매일경제  2022.05.14 10:06
# 5       ‘4대 그룹 중 유일한 공개채용’ 삼성 GSAT 이틀간 온라인 진행   헤럴드경제  2022.05.14 09:05
# 6   삼성 18개 계열사 채용고시 시작…GSAT 오늘부터 이틀간 온라인 진...    한국경제  2022.05.14 08:41
# 7           ‘4대그룹 유일 공채’ 삼성, 오늘부터 온라인 GSAT 실시    조선비즈  2022.05.14 08:19

# %% [markdown]
# ## 반복문을 사용해 10페이지까지 수집
# * 위에서 만든 함수를 활용합니다.
# * time.sleep() 을 통해 데이터를 쉬었다 가져옵니다.

# %%
import time
from tqdm import trange

page_no = 0
news_list = []
for page_no in trange(1,11):
    df_temp = news_list.append(get_one_page_news(item_code, page_no))
    time.sleep(0.1)
    news_list.append(df_temp)
    
news_list
# Out:
# 100%|██████████| 10/10 [00:02<00:00,  4.17it/s]
# [                                      제목    정보제공                날짜
#  0      기관 '사자'에 코스피·코스닥 동반 상승…삼성전자 1%대 ↑   아시아경제  2022.05.17 11:07
#  1   대기업 1분기 매출 800조 육박 '사상 최대'…삼성 압도적 1위    한국경제  2022.05.17 10:54
#  2              비스포크 인기에 에어컨 생산 풀가동 나선 삼성    매일경제  2022.05.17 10:44
#  4     비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’    이데일리  2022.05.17 09:51
#  5     삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'   아시아경제  2022.05.17 09:07
#  6       여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’   헤럴드경제  2022.05.17 08:58
#  7         비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동   머니투데이  2022.05.17 08:43
#  8    삼성운용, 美 ETF 산업·中 메타버스 ETF 등 2종 신규상장   머니투데이  2022.05.17 10:35
#  10      "美ETF산업·中메타버스 투자"…삼성운용 ETF 2종 상장    이데일리  2022.05.17 09:21
#  11     삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장  파이낸셜뉴스  2022.05.17 09:20
#  12          삼성家 사돈의 유통혁명…편의점이 마트·백화점 제쳤다   헤럴드경제  2022.05.17 10:32
#  13       대기업 1분기 매출 800조원 육박…삼성전자 부동의 1위  한경비즈니스  2022.05.17 10:10
#  14    삼성 반도체 핵심기술 중국에 유출…800억 챙긴 일당 '덜미'    한국경제  2022.05.17 09:20
#  15       코스피, 기관 매수에 상승 출발…삼성전자 6.7만원 회복    한국경제  2022.05.17 09:17
#  16     [1일IT템]삼성전자 "로블록스에서 팝스타의 꿈 도전하세요"  파이낸셜뉴스  2022.05.17 08:51
#  17      포브스 "삼성, 세계 기술기업 2위→4위...공급망 발목"   머니투데이  2022.05.17 08:12
#  0     비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’    이데일리  2022.05.17 09:51
#  1     삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'   아시아경제  2022.05.17 09:07
#  2       여름 대목에 대비…삼성전자 2월부터 에어컨 공장 ‘풀가동’   헤럴드경제  2022.05.17 08:58
#  3         비스포크 무풍 갤러리 인기…삼성 에어컨 생산라인 풀가동   머니투데이  2022.05.17 08:43
#  0       "美ETF산업·中메타버스 투자"…삼성운용 ETF 2종 상장    이데일리  2022.05.17 09:21
#  1      삼성운용, 세계최초 '中메타버스' 투자 ETF 등 2종 상장  파이낸셜뉴스  2022.05.17 09:20,
#  None,
#                                             제목    정보제공                날짜
#  0              TSMC보다 한 발 빨랐다…삼성이 꺼낸 '비장의 무기'    한국경제  2022.05.16 21:02
#  1                        삼성전자 5대 매출처에 퀄컴 첫 등장    매일경제  2022.05.16 19:55
#  3                   삼성전자, 1분기 5대 매출처에 퀄컴 첫 포
#  9      “삼전 효과 빠졌네...”삼성화재, 1분기 순익 5.2% 감소   이데일리  2022.05.12 10:46
#  10         갤럭시 워치에 구글 어시스턴트 담긴다…삼성 시너지 속도   서울경제  2022.05.12 10:24
#  11   삼성 '갤럭시Z폴드4' 모습 보니…달라진 종횡비·카메라 눈에 띄어   매일경제  2022.05.12 09:26
#  12            삼성전자, 1% 가까이 하락해 6.5만원 '위태'   이데일리  2022.05.12 09:16
#  13    엔데믹에 메모리시장 먹구름…삼성, '기업용 SSD'로 선제 대응   이데일리  2022.05.12 08:49
#  14     삼성전자, 영국서 'Neo QLED 8K' 핵심 기술 선보인다  머니투데이  2022.05.12 08:33
#  15  "1.4나노 간다" 초조함 드러낸 TSMC…삼성은 3나노 추월 집중  머니투데이  2022.05.12 05:03
#  0    삼성전자, 英 런던서 TV 핵심기술 소개…‘유럽 테크세미나’ 개최   서울경제  2022.05.12 09:50
#  1          삼성전자, 영국서 '네오 QLED 8K' 핵심기술 선봬   이데일리  2022.05.12 09:47
#  2        삼성전자, 영국서 'Neo QLED 8K' 핵심 기술 선봬  아시아경제  2022.05.12 08:05
#  0      “삼전 효과 빠졌네...”삼성화재, 1분기 순익 5.2% 감소   이데일리  2022.05.12 10:46,
#  None]

# %% [markdown]
# ## 위에서 수집한 데이터는 news_list 라는 변수에 들어있습니다. 판다스를 활용해 하나의 데이터프레임으로 만들어 주세요.
#
# * concat :
#     * axis=0 행을 기준으로 위아래로 같은 컬럼끼리 값을 이어 붙여 새로운 행을 만듦
#     * axis=1 컬럼을 기준으로 인덱스가 같은 값을 옆으로 붙여 새로운 컬럼을 만듦

# %%
# df_news


#df_news = pd.concat(news_list, ignore_index = True)

df_news = pd.concat(news_list).reset_index(drop=True)

# %% [markdown]
# ## 파일로 저장하기
#
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg">

# %%
file_name = f"news_{item_code}_{item_name}.csv"
file_name
# Out:
# 'news_005930_삼성전자.csv'

# %%
# to_csv


df_news.to_csv(file_name, index=False)

# %%
# read_csv
pd.read_csv(file_name)
# Out:
#                                         제목   정보제공                날짜
# 0        기관 '사자'에 코스피·코스닥 동반 상승…삼성전자 1%대 ↑  아시아경제  2022.05.17 11:07
# 1     대기업 1분기 매출 800조 육박 '사상 최대'…삼성 압도적 1위   한국경제  2022.05.17 10:54
# 2                비스포크 인기에 에어컨 생산 풀가동 나선 삼성   매일경제  2022.05.17 10:44
# 3       비스포크 무풍에어컨 인기…삼성전자 생산라인 2월부터 ‘풀가동’   이데일리  2022.05.17 09:51
# 4       삼성전자 에어컨 생산라인 풀가동 중…'무풍에어컨 갤러리 효과'  아시아경제  2022.05.17 09:07
# ..                                     ...    ...               ...
# 195  "1.4나노 간다" 초조함 드러낸 TSMC…삼성은 3나노 추월 집중  머니투데이  2022.05.12 05:03
# 196   삼성전자, 英 런던서 TV 핵심기술 소개…‘유럽 테크세미나’ 개최   서울경제  2022.05.12 09:50
# 197         삼성전자, 영국서 '네오 QLED 8K' 핵심기술 선봬   이데일리  2022.05.12 09:47
# 198       삼성전자, 영국서 'Neo QLED 8K' 핵심 기술 선봬  아시아경제  2022.05.12 08:05
# 199     “삼전 효과 빠졌네...”삼성화재, 1분기 순익 5.2% 감소   이데일리  2022.05.12 10:46
#
# [200 rows x 3 columns]
